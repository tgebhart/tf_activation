# %%
import os
import sys
import progressbar

import dionysus as dion
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from tf_activation.functions.persistence_landscape import persistence_landscape, average_landscape
import seaborn as sns
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
base_loc = '/home/gebha095/projects/tf_activation/logdir/data/experiments/filtrations/cff_wc15-5-32_wfc11024_seed1_normalstd2p0_relu/p99_mnist_SGD1p0e-04_100epochs_128batch'
t_t_type = 'train'

# %%
classes = list(range(10))

# %%
diagram_df = []

for c in classes:
    print('Class: {}'.format(c))
    c_loc = os.path.join(base_loc,str(c))
    for filtration_file in os.listdir(c_loc):
        
        if filtration_file.find(t_t_type) != -1:
            r = np.genfromtxt(os.path.join(c_loc, filtration_file), delimiter=',')

            max_eps = r[0]
            f = dion.Filtration()
            for i in range(r.shape[0]):
                f.append(dion.Simplex([i+1], r[i]))
                f.append(dion.Simplex([2*(i+1)], r[i]))
                f.append(dion.Simplex([i+1, 2*(i+1)], r[i]))
            f.sort(reverse=True)

            m = dion.homology_persistence(f)
            dgms = dion.init_diagrams(m, f)

            ex = filtration_file[:filtration_file.find('_')]
            diagram_df.append({'class': c, 'diagrams':dgms, 'example':ex, 'max_filtration':max_eps})
# Out:
# Class: 0
# Class: 1
# Class: 2
# Class: 3
# Class: 4
# Class: 5
# Class: 6
# Class: 7
# Class: 8
# Class: 9

# %%
diagram_df = pd.DataFrame(diagram_df)

# %%
diagram_df.head()
# Out:
#    class                                           diagrams example  \
# 0      0  [((5.64082,inf), (5.64082,inf), (5.64082,inf),...     512
# 1      0  [((5.64082,inf), (5.64082,inf), (5.59658,inf),...     286
# 2      0  [((5.64082,inf), (5.64082,inf), (5.6187,inf), ...     525
# 3      0  [((5.6187,inf), (5.6187,inf), (5.6187,inf), (5...     202
# 4      0  [((5.64082,inf), (5.64082,inf), (5.59658,inf),...     881
#
#    max_filtration
# 0        5.640817
# 1        5.640817
# 2        5.640817
# 3        5.618697
# 4        5.640817

# %%
H = 0
EVERY = 10

# %%
def remove_infs(dgm, m=0):
    return dion.Diagram([(p.birth, p.death) if p.death < float('Inf') else (p.birth, m) for p in dgm])

# %%
dist_dim = diagram_df.shape[0]
print('Number rows: {}'.format(dist_dim))
dists = np.zeros(shape=(dist_dim//EVERY+1,dist_dim//EVERY+1))
cols = np.empty(shape=(dist_dim//EVERY))

bar = progressbar.ProgressBar(maxval=dist_dim, \
    widgets=[progressbar.Bar('=', '[', ']'), ' ', progressbar.Percentage()])
bar.start()
for i in range(0,dist_dim,EVERY):
    print(i, '/', dist_dim)
    for j in range(0,dist_dim,EVERY):
        if i != j:
            d1 = remove_infs(diagram_df['diagrams'].iloc[i][H], diagram_df['max_filtration'].iloc[i])
            d2 = remove_infs(diagram_df['diagrams'].iloc[j][H], diagram_df['max_filtration'].iloc[j])
            dists[i//EVERY,j//EVERY] = dion.wasserstein_distance(d1, d2, q=2)
    cols[i//EVERY] = diagram_df['class'].iloc[i]
# Out:
# [                                                                        ]   0%
# Number rows: 1000
# 0 / 1000
# 10 / 1000
# 20 / 1000
# 30 / 1000
# 40 / 1000
# 50 / 1000
# 60 / 1000
# 70 / 1000
# 80 / 1000
# 90 / 1000
# 100 / 1000
# 110 / 1000
# 120 / 1000
# 130 / 1000
# 140 / 1000
# 150 / 1000
# 160 / 1000
# 170 / 1000
# 180 / 1000
# 190 / 1000
# 200 / 1000
# 210 / 1000
# 220 / 1000
# 230 / 1000
# 240 / 1000
# 250 / 1000
# 260 / 1000
# 270 / 1000
# 280 / 1000
# 290 / 1000
# 300 / 1000
# 310 / 1000
# 320 / 1000
# 330 / 1000
# 340 / 1000
# 350 / 1000
# 360 / 1000
# 370 / 1000
# 380 / 1000
# 390 / 1000
# 400 / 1000
# 410 / 1000
# 420 / 1000
# 430 / 1000
# 440 / 1000
# 450 / 1000
# 460 / 1000
# 470 / 1000
# 480 / 1000
# 490 / 1000
# 500 / 1000
# 510 / 1000
# 520 / 1000
# 530 / 1000
# 540 / 1000
# 550 / 1000
# 560 / 1000
# 570 / 1000
# 580 / 1000
# 590 / 1000
# 600 / 1000
# 610 / 1000
# 620 / 1000
# 630 / 1000
# 640 / 1000
# 650 / 1000
# 660 / 1000
# 670 / 1000
# 680 / 1000
# 690 / 1000
# 700 / 1000
# 710 / 1000
# 720 / 1000
# 730 / 1000
# 740 / 1000
# 750 / 1000
# 760 / 1000
# 770 / 1000
# 780 / 1000
# 790 / 1000
# 800 / 1000
# 810 / 1000
# 820 / 1000
# 830 / 1000
# 840 / 1000
# 850 / 1000
# 860 / 1000
# 870 / 1000
# 880 / 1000
# 890 / 1000
# 900 / 1000
# 910 / 1000
# 920 / 1000
# 930 / 1000
# 940 / 1000
# 950 / 1000
# 960 / 1000
# 970 / 1000
# 980 / 1000
# 990 / 1000

# %%
df = pd.DataFrame(dists)
# dists_df = df.drop(27).drop(27, axis=1)
sns.heatmap(df)

# %%
sns.heatmap(df.drop(5).drop(5, axis=1))

# %%
tdf = df.where(np.triu(np.ones(df.shape)).astype(np.bool))
sdf = pd.Series(tdf.values.ravel())

# %%
sdf.describe()
# Out:
# count    5151.000000
# mean       15.339353
# std        17.362623
# min         0.000000
# 25%         3.827547
# 50%         6.356766
# 75%        27.417162
# max       104.570183
# dtype: float64

# %%
sdfdr = pd.Series(tdf.drop(5).drop(5, axis=1).values.ravel())

# %%
sdfdr.describe()
# Out:
# count    5050.000000
# mean       13.664996
# std        12.669190
# min         0.000000
# 25%         3.769753
# 50%         6.225943
# 75%        26.111545
# max        40.351803
# dtype: float64

# %%
avg = sdfdr.mean()
std = sdfdr.std()
med = sdfdr.median()
print(med)
avg + std
# Out:
# 6.225943326950073
# 26.33418594458971

# %%
bigs = df[df > med].replace(np.NaN, 0)
bigs = bigs[bigs.astype(bool).sum(axis=1) > 50].reset_index()
bigs
# Out:
#     index           0           1           2           3           4  \
# 0       0    0.000000   36.535545   36.539421   36.642464   36.632751
# 1       5  103.737251  100.801437  100.846642  100.693893  100.835190
# 2       6   37.045517    6.759357    7.396963    0.000000    7.581100
# 3       8   18.712097   31.423401   31.522154   31.468891   31.523737
# 4       9   19.726583   30.786757   30.878395   30.824865   30.924080
# 5      12   37.282761    7.938881    8.513471    0.000000    8.513912
# 6      15   37.144459    6.454658    6.939959    7.139340    0.000000
# 7      16   20.218317   30.955391   30.847124   31.440199   30.799360
# 8      22   37.228413    6.795619    7.220800    7.832572    6.425999
# 9      24   37.266396    6.572352    6.788274    8.441887    0.000000
# 10     25   18.563210   31.293337   31.370979   31.435307   31.368385
# 11     26   20.086668   32.003372   32.135750   31.598217   32.191002
# 12     28   24.419085   27.629129   27.777477   27.411743   27.842476
# 13     36   37.049412    6.782560    7.419234    0.000000    7.599312
# 14     37   19.501108   31.193262   31.202440   31.584623   31.078745
# 15     38   37.007854    0.000000    0.000000    7.988220    0.000000
# 16     40   19.612917   30.893373   30.950575   31.174149   30.858147
# 17     41    9.179377   36.355965   36.439552   36.516129   36.335140
# 18     42   36.993923    6.524503    7.148247    0.000000    7.421082
# 19     43   14.173881   38.678864   38.708435   39.070835   38.534512
# 20     48   37.126602    0.000000    0.000000    7.957537    0.000000
# 21     49   14.124739   39.288834   39.343422   39.119759   39.476772
# 22     51   28.916775   22.502520   22.630638   22.749084   22.532795
# 23     54   28.416397   23.050276   23.039454   23.460632   23.012518
# 24     56   12.183978   36.074093   36.055626   36.556488   35.877102
# 25     57   25.121010   30.807270   30.784641   31.373171   30.389318
# 26     60   37.440247    7.356172    7.164139    9.578008    0.000000
# 27     63   28.802647   22.661917   22.811939   22.771461   22.748253
# 28     64   26.780994   26.792669   26.961359   26.305895   26.992378
# 29     65   29.582951   22.583117   22.665001   23.136513   22.401217
# 30     67   30.357548   23.458307   23.307327   24.225538   23.014290
# 31     73   19.135578   31.378704   31.506908   31.321915   31.491413
# 32     77   29.056091   23.235229   23.357059   23.512087   23.156757
# 33     91   36.978661    0.000000    0.000000    7.659454    0.000000
# 34     93   37.199841    7.526330    8.117381    0.000000    8.206755
#
#              5           6           7           8 ...           91  \
# 0   103.737289   37.045811   36.567375   18.712500 ...    36.978451
# 1     0.000000  100.566628  100.742035  102.013329 ...   100.922958
# 2   100.567650    0.000000    0.000000   31.895781 ...     9.149334
# 3   102.013611   31.896774   31.455244    0.000000 ...    31.920849
# 4   101.827820   31.273478   30.786459    6.418082 ...    31.360371
# 5   100.492645    0.000000    6.959300   32.168148 ...     9.777686
# 6   100.719193    7.452501    7.074229   31.994669 ...     6.731359
# 7   102.049507   31.972122   31.246931    8.259092 ...    30.836956
# 8   100.754456    8.220044    7.707610   32.091423 ...     6.491095
# 9   100.893417    9.252231    8.087077   32.160915 ...     0.000000
# 10  102.045296   31.918110   31.376698    0.000000 ...    31.731007
# 11  101.787544   31.324526   31.761196    7.138361 ...    32.626144
# 12  101.110138   27.688641   27.492313   15.584472 ...    28.367863
# 13  100.566086    0.000000    0.000000   31.902845 ...     9.158622
# 14  102.055054   32.057888   31.452997    6.963280 ...    31.128809
# 15  101.007904    9.787910    7.313260   32.030972 ...     0.000000
# 16  101.929176   31.655085   31.090649    0.000000 ...    31.034277
# 17  103.591995   36.818848   36.476177   18.492336 ...    36.400639
# 18  100.583824    0.000000    0.000000   31.841846 ...     9.083787
# 19  104.544678   39.340874   38.959225   23.200045 ...    38.373363
# 20  100.887108    9.054657    7.451421   32.020287 ...     0.000000
# 21  104.569618   39.365925   39.142265   23.328606 ...    39.921703
# 22  101.035629   23.347582   22.680178   21.994841 ...    22.877949
# 23  101.198860   24.159256   23.282162   21.510792 ...    23.352701
# 24  103.653755   36.866928   36.429913   18.647568 ...    35.649303
# 25  102.091537   31.553316   31.281412   16.657213 ...    29.721785
# 26  101.036972   10.536438    9.119163   32.445210 ...     0.000000
# 27  101.000061   23.330330   22.749146   21.818897 ...    23.184755
# 28  100.919708   25.899834   26.513393   19.033302 ...    27.469931
# 29  101.004959   23.577028   22.983936   22.835529 ...    22.251442
# 30  101.336128   24.734020   24.033285   23.960073 ...    22.487005
# 31  101.931297   31.651876   31.358479    0.000000 ...    31.883821
# 32  101.058884   23.811787   23.478407   22.101248 ...    23.193897
# 33  100.919014    9.149261    7.012867   31.921427 ...     0.000000
# 34  100.522690    0.000000    6.454935   32.069309 ...     9.645440
#
#             92          93          94          95          96          97  \
# 0    36.577915   37.199841   36.707039   36.665581   36.746368   36.614620
# 1   100.750320  100.522568  100.778870  100.797737  100.731468  100.706215
# 2     0.000000    0.000000    6.915253    6.946631    6.510253    0.000000
# 3    31.398335   32.068596   31.526690   31.493361   31.555071   31.422489
# 4    30.774843   31.449980   30.929842   30.891228   30.962738   30.786985
# 5     7.267672    0.000000    7.880518    7.994789    7.310190    6.487462
# 6     0.000000    7.405622    0.000000    0.000000    0.000000    0.000000
# 7    31.103052   32.141560   31.014757   30.978395   31.116680   31.315256
# 8     6.327540    8.077175    0.000000    0.000000    0.000000    6.799611
# 9     6.454393    9.465641    0.000000    0.000000    0.000000    7.343986
# 10   31.310720   32.090664   31.415579   31.376440   31.462135   31.377344
# 11   31.853785   31.429253   32.052647   32.052021   31.979658   31.675865
# 12   27.487888   27.884926   27.709585   27.682674   27.686504   27.418509
# 13    0.000000    0.000000    6.930260    6.965492    6.522503    0.000000
# 14   31.245811   32.216682   31.157742   31.147858   31.236799   31.423948
# 15    6.359106   10.314198    0.000000    0.000000    0.000000    7.404477
# 16   30.910196   31.815636   30.882919   30.861561   30.951361   31.036278
# 17   36.288914   36.939835   36.193192   36.223141   36.186497   36.365253
# 18    0.000000    0.000000    6.801849    6.806703    6.436593    0.000000
# 19   38.700371   39.438133   38.509720   38.540974   38.540249   38.866184
# 20    0.000000    9.408353    0.000000    0.000000    0.000000    6.861257
# 21   39.248070   39.500652   39.451714   39.422367   39.448013   39.182190
# 22   22.462559   23.571465   22.478024   22.442589   22.540415   22.568699
# 23   23.163847   24.389025   23.187845   23.137548   23.293230   23.331280
# 24   36.148422   36.984585   35.937241   35.946018   36.013893   36.353535
# 25   30.851776   31.578993   30.447769   30.490536   30.488440   31.099270
# 26    7.811503   10.882090    6.394734    6.538195    6.736681    8.689450
# 27   22.559509   23.555941   22.659454   22.624161   22.695637   22.615641
# 28   26.600908   25.910288   26.801653   26.820375   26.687258   26.398500
# 29   22.568373   23.741831   22.277245   22.334160   22.288828   22.798351
# 30   23.643606   24.914133   23.296207   23.300390   23.414423   23.946714
# 31   31.269053   31.820080   31.382973   31.361446   31.382685   31.250994
# 32   23.120499   23.933302   22.912714   22.974710   22.824354   23.232908
# 33    0.000000    9.645409    0.000000    0.000000    0.000000    6.682603
# 34    6.824804    0.000000    7.595330    7.648564    7.146881    0.000000
#
#             98          99  100
# 0    36.785286   36.740696  0.0
# 1   100.830559  100.668884  0.0
# 2     7.856078    0.000000  0.0
# 3    31.642582   31.541725  0.0
# 4    31.058741   30.928789  0.0
# 5     8.680837    0.000000  0.0
# 6     0.000000    0.000000  0.0
# 7    30.905764   31.412838  0.0
# 8     0.000000    0.000000  0.0
# 9     0.000000    6.856688  0.0
# 10   31.496216   31.505083  0.0
# 11   32.274788   31.652124  0.0
# 12   27.960850   27.486750  0.0
# 13    7.869158    0.000000  0.0
# 14   31.089504   31.504650  0.0
# 15    0.000000    7.762246  0.0
# 16   30.890499   31.125917  0.0
# 17   36.226395   36.339169  0.0
# 18    7.761814    0.000000  0.0
# 19   38.405014   38.848625  0.0
# 20    0.000000    6.570377  0.0
# 21   39.633312   39.306225  0.0
# 22   22.563360   22.691618  0.0
# 23   23.194899   23.504025  0.0
# 24   35.780685   36.357632  0.0
# 25   30.165813   30.944532  0.0
# 26    0.000000    8.527393  0.0
# 27   22.807871   22.743725  0.0
# 28   27.055609   26.312351  0.0
# 29   22.167755   22.749668  0.0
# 30   22.961813   23.974888  0.0
# 31   31.542925   31.315170  0.0
# 32   22.954113   23.046774  0.0
# 33    0.000000    6.808958  0.0
# 34    8.447262    0.000000  0.0
#
# [35 rows x 102 columns]

# %%
bigs = bigs['index'].values
bigs
# Out:
# array([ 0,  5,  6,  8,  9, 12, 15, 16, 22, 24, 25, 26, 28, 36, 37, 38, 40,
#        41, 42, 43, 48, 49, 51, 54, 56, 57, 60, 63, 64, 65, 67, 73, 77, 91,
#        93])

# %%
OF_INTEREST = 27

# %%
# dists_df[OF_INTEREST]

# %%
dion.plot.plot_diagram(diagram_df['diagrams'].iloc[OF_INTEREST*EVERY][0], show=True)

# %%
diagram_df.iloc[OF_INTEREST*EVERY]
# Out:
# class                                                             2
# diagrams          [((5.64082,inf), (5.64082,inf), (5.6187,inf), ...
# example                                                         724
# max_filtration                                              5.64082
# Name: 270, dtype: object

# %%
mnumber = int(diagram_df['example'].iloc[OF_INTEREST*EVERY])
big_nums = list(map(lambda x: int(x), diagram_df['example'].iloc[bigs*EVERY]))

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
# Out:
# WARNING:tensorflow:From <ipython-input-23-ffcb05fb42c8>:5: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/gebha095/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/gebha095/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /home/gebha095/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/gebha095/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/gebha095/.local/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
image = mnist.train.images[mnumber]
plt.subplot(1, 3, 1)
plt.imshow(np.reshape(image, (28,28)))

# plt.subplot(1, 3, 3)
# plt.imshow(np.reshape(adv, (28,28)) - np.reshape(image, (28,28)))

# %%
from tf_activation.models.cff import CFF_Model
model = CFF_Model(W_conv1=[5,5,1,32])

model_directory = '/home/gebha095/projects/tf_activation/logdir/models/cff_wc15-5-32_wfc11024_seed1_normalstd2p0_relu'
model.infer_graph_parameters_from_filename(model_directory)
trained_model = 'mnist_SGD1p0e-04_100epochs_128batch/model.ckpt'
training_parameters = model.infer_training_parameters_from_filename(trained_model)
# Out:
# mnist_SGD1.0e-04_100epochs_128batch

# %%
tf.reset_default_graph()
with tf.device('/cpu:0'):
        # Create the model
    x = tf.placeholder(tf.float32, [None, 784])

    # Define loss and optimizer
    y_ = tf.placeholder(tf.float32, [None, 10])

    # Build the graph for the deep net
    net = model.build_graph(x)
    if not model.implements_dropout:
        keep_prob = tf.placeholder(tf.float32)

    logits = model.get_output_layer()
    cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=logits))
    train_step = model.get_train_step(cross_entropy, training_parameters['optimizer'], lr=training_parameters['learning_rate'])
    correct_prediction = tf.equal(tf.argmax(model.get_output_layer(), 1), tf.argmax(y_, 1))
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

    saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-26-240070107946>:15: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See `tf.nn.softmax_cross_entropy_with_logits_v2`.

# %%
# X = np.take(mnist.train.images, big_nums, axis=0)
# Y = np.take(mnist.train.labels, big_nums, axis=0)
X = mnist.train.images
Y = mnist.train.labels
with tf.Session() as sess:
    
    saver.restore(sess, os.path.join(model_directory, trained_model))
    
    acc = accuracy.eval(feed_dict={
                x: X, y_: Y, keep_prob: 1.0})

    loss = cross_entropy.eval(feed_dict={x: X, y_: Y, keep_prob:1.0})
    
    print('Accuracy: {} , Loss: {}'.format(acc,loss))
# Out:
# INFO:tensorflow:Restoring parameters from /home/gebha095/projects/tf_activation/logdir/models/cff_wc15-5-32_wfc11024_seed1_normalstd2p0_relu/mnist_SGD1p0e-04_100epochs_128batch/model.ckpt
# Accuracy: 0.11621817946434021 , Loss: 5.243537425994873

# %%
for i in bigs:
    dion.plot.plot_diagram(diagram_df['diagrams'].iloc[i*EVERY][0], show=True)

# %%
for i in range(100):
    if i not in bigs:
        dion.plot.plot_diagram(diagram_df['diagrams'].iloc[i*EVERY][0], show=True)

# %%
no_inf = remove_infs(diagram_df['diagrams'].iloc[1][H], diagram_df['max_filtration'].iloc[1])
landscape = persistence_landscape(no_inf, dionysus_diagram=True)

# %%
def plot_landscape(L, cls, every=100, max=25):

    ax = plt.subplot(111,projection='3d')
    # ax = plt.subplot()
    for i in range(0, max):

        xs = []
        ys = []
        zs = []
        for l in L[i]:
            if abs(l[0]) != float('Inf') and abs(l[1]) != float('Inf'):
                xs.append(l[0])
                ys.append(i)
                zs.append(l[1])

        plt.plot(xs, ys, zs)

    # now plot both limits against eachother

    # ax.set_aspect('equal')
    plt.xlabel('Birth Time')
    plt.ylabel('Death Time')
    plt.title('Class {}'.format(cls))
    plt.show()

# %%
plot_landscape(landscape, 0)

# %%
no_inf1 = remove_infs(diagram_df['diagrams'].iloc[1][H], diagram_df['max_filtration'].iloc[1])
no_inf2 = remove_infs(diagram_df['diagrams'].iloc[2][H], diagram_df['max_filtration'].iloc[2])


landscape1 = persistence_landscape(no_inf1, dionysus_diagram=True)
landscape2 = persistence_landscape(no_inf2, dionysus_diagram=True)

avg_landscapes = average_landscape([landscape1, landscape2])
# Out:
# in else
# in else

# %%
plot_landscape(landscape1, 0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_landscape(landscape2, 0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plot_landscape(avg_landscapes, 0)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dion.plot.plot_diagram(diagram_df['diagrams'].iloc[1][0], show=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def plot_diagram(d, cls):

    ax = plt.subplot()
    diag = d[~np.isinf(d[:,1])]
    ax.scatter(diag[:,0], diag[:,1], s=25, c=(diag[:,0] - diag[:,1])**2, cmap=plt.cm.coolwarm, zorder=10)
    lims = [
        np.min(0.85*diag[:,0]),  # min of both axes
        np.max(1.15*diag[:,1]),  # max of both axes
    ]

    # now plot both limits against eachother

    ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
    ax.set_aspect('equal')
    ax.set_xlim(lims)
    ax.set_ylim(lims)
    plt.xlabel('Birth Time')
    plt.ylabel('Death Time')
    plt.title('Class {}'.format(cls))

    plt.show()
    
def diag_to_numpy(diag):
    ret = np.empty(shape=(len(diag),2))
    i = 0
    for p in diag:
        ret[i,0] = p.birth
        ret[i,1] = p.death
        i += 1
    return ret

# %%
plot_diagram(diag_to_numpy(no_inf1), 0)
# Out:
# <img src="data:image/png;base64,..." width="640">
