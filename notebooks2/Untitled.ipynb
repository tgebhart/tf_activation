# %%
# %load_ext autoreload
# %autoreload 2

# %%
from tf_activation.models.cff import CFF_Model
from tf_activation.models.fff import FFF_Model
import numpy as np
import pandas as pd
from tensorflow.examples.tutorials.mnist import input_data
import matplotlib.pyplot as plt

import os

# %%
df = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc13-3-16_wfc11024_seedNone_relu/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')

# %%
df.head()
# Out:
#    epoch  persistence_score  test_accuracy  train_accuracy
# 0      0           0.000060         0.1075           0.085
# 1      1           0.000062         0.1452           0.105
# 2      2           0.000064         0.1864           0.143
# 3      3           0.000067         0.2385           0.178
# 4      4           0.000070         0.3020           0.207

# %%
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df['epoch'], np.log(df['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df['epoch'], df['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df2 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seed1_uniformstd2p0_relu/h0_p99p0_mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df2['epoch'], np.log(df2['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df2['epoch'], df2['test_loss'], 'ro-', linewidth=1, markersize=6)

# %%
df3 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc13-3-16_wfc11024_seedNone_relu/mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df3['epoch'], np.log(df3['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df3['epoch'], df3['train_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df4 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/fff_wfc11024_wfc21024_wfc310_seedNone_relu/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df4['epoch'], np.log(df4['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df4['epoch'], df4['train_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df6 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc13-3-16_wfc11024_seedNone_relu/mnist_SGD1p0e-04_1000epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df6['epoch'], np.log(df6['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df6['epoch'], df6['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df7 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/ccff_wc15-5-16_wc23-3-32_wfc11024_seedNone_relu/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df7['epoch'], (df7['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df7['epoch'], df7['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/ccff_wc15-5-16_wc25-5-32_wfc11024_seedNone_relu/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df8['epoch'], df8['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df9 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_relu/13579/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df9['epoch'], np.log(df9['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df9['epoch'], df9['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df9 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_relu/02468/mnist_SGD1p0e-04_51epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df9['epoch'], np.log(df9['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df9['epoch'], df9['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/ccff_wc15-5-16_wc25-5-32_wfc11024_seedNone_relu/mnist_SGD1p0e-04_1000epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df8['epoch'], df8['test_accuracy'], 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_relu/h0_mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df8['epoch'], (df8['test_accuracy']), 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_std5p0_relu/h0_p99p5_mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('accuracy')
axa.plot(df8['epoch'], (df8['test_accuracy']), 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_std5p0_relu/h0_p99p5_mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('loss')
axa.plot(df8['epoch'], (df8['train_loss']), 'ro-', linewidth=1, markersize=6)

# %%
df8 = pd.read_pickle('/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seedNone_uniformstd2p0_relu/co_h0_p99p0_mnist_SGD1p0e-04_100epochs_128batch/resdf.pkl')
fig, axp = plt.subplots()


axp.set_xlabel('epoch')
axp.set_ylabel('persistence score')
axp.plot(df8['epoch'], (df8['persistence_score']), 'bo-', linewidth=1, markersize=6)

axa = axp.twinx()
axa.set_ylabel('loss')
axa.plot(df8['epoch'], (df8['train_accuracy']), 'ro-', linewidth=1, markersize=6)

# %%
mnist = input_data.read_data_sets('MNIST_data', one_hot=True)
adv_loc = '/home/gebha095/projects/tf_activation/logdir/adversaries/cff_wc15-5-32_wfc11024_seedNone_normalstd2p0_relu/mnist_SGD1p0e-04_100epochs_128batch'
cls = 6
correct = 6
image = mnist.train.images[71]
adv = np.load(os.path.join(adv_loc, str(cls), 'adversary_correct_{}.npy'.format(correct)))
plt.subplot(1, 3, 1)
plt.imshow(np.reshape(image, (28,28)))

plt.subplot(1, 3, 2)
plt.imshow(np.reshape(adv, (28,28)))

plt.subplot(1, 3, 3)
plt.imshow(np.reshape(adv, (28,28)) - np.reshape(image, (28,28)))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
import dionysus as d

# %%
diag = d.Diagram()

# %%
diag_loc = '/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seed1_uniformstd2p0_relu/h0_p99p0_mnist_SGD1p0e-04_100epochs_128batch/diagram_0.csv'
mat = np.loadtxt(diag_loc, delimiter=',')
f = d.Filtration()
for i in range(mat.shape[0]):
    birth = mat[i,2]
    death = mat[i,3]
    bv = mat[i,0]
    dv = mat[i,1]
    f.append(d.Simplex([birth], bv))
    f.append(d.Simplex([death], dv))
    f.append(d.Simplex(([birth, death], t)))
# Out:
# /home/gebha095/.local/lib/python3.5/site-packages/ipykernel_launcher.py:2: UserWarning: loadtxt: Empty input file: "/home/gebha095/projects/tf_activation/logdir/data/experiments/diagrams/cff_wc15-5-32_wfc11024_seed1_uniformstd2p0_relu/h0_p99p0_mnist_SGD1p0e-04_100epochs_128batch/diagram_0.csv"
